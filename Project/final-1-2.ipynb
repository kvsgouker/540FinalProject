# %%
# pip install lxml
#!pip install SciPy
#!pip install python-Levenshtein
#!pip install fuzzywuzzy
# Out:
# Requirement already satisfied: SciPy in c:\users\kyles\anaconda3\lib\site-packages (1.9.1)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in c:\users\kyles\anaconda3\lib\site-packages (from SciPy) (1.21.5)
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.22.0-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.22.0
#   Downloading Levenshtein-0.22.0-cp39-cp39-win_amd64.whl (101 kB)
#      -------------------------------------- 101.0/101.0 kB 1.5 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0
#   Downloading rapidfuzz-3.3.1-cp39-cp39-win_amd64.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 6.1 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.22.0 python-Levenshtein-0.22.0 rapidfuzz-3.3.1

# %%
import time

# file system searches etc
import os
from os.path import basename, exists
import glob

# regular expressions
import re
import math
import random

# data frames and smart arrays etc
import pandas as pd
import numpy as np

# web access and html parsing (urllib, its submodules)
import requests
import urllib
import urllib.request
import urllib.error
from urllib.request import urlretrieve
import ssl


# parser of web pages
from bs4 import BeautifulSoup
# more efficient parsing.
import lxml

# for plots
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Fuzzy string matching
from fuzzywuzzy import fuzz

# for accessing sql
import sqlite3

# fancy table printing
from tabulate import tabulate

# %%
# For testing: Make warnings fatal.

import warnings
warnings.filterwarnings("error")

# %%
# Constants

FINAL_DATA_DIRECTORY = "data/final"

# Check if the directory exists
if not os.path.exists(FINAL_DATA_DIRECTORY):
    # If it doesn't exist, create it
    os.makedirs(FINAL_DATA_DIRECTORY)
    print(f"Directory '{FINAL_DATA_DIRECTORY}' created.")
# Out:
# Directory 'data/final' created.

# %%
QUEUE_TIMES_API = "https://queue-times.com/en-US/pages/api"
WIKIPEDIA_PARK_RANKINGS = "https://en.wikipedia.org/wiki/List_of_amusement_park_rankings"
WIKIPEDIA_PARK_RANKINGS_FILE = FINAL_DATA_DIRECTORY+"/amusement_park_rankings.html"
RCDB_CSV_FILE = FINAL_DATA_DIRECTORY+"/coaster_db.csv"
RCSB_URL = "https://github.com/RobMulla/twitch-stream-projects/blob/main/001-rollercoaster-dataset/dbv1.csv"
QUEUE_TIMES_PARK_LIST_URL = "https://queue-times.com/en-US/parks?group=country"

# %%
# General Functions

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36"
}

# download: A good citizen download function
#     url - the url accessed
#     destination - local file to write
#
# respects code 429 and waits instead of pounding.

# Function to disable SSL certificate verification
def disable_ssl_verification():
    ssl._create_default_https_context = ssl._create_unverified_context

# Call the function to disable SSL verification
# This is to workaround an SSL certificate error I am getting.
disable_ssl_verification()

def download(url, destination, secure=True):
    try:
        # Send a GET request with headers
        response = requests.get(url, headers=headers, verify=secure)
        # Check if the request was successful
        if response.status_code == 200:
            with open(destination, 'w') as f:
                f.write(response.text)
            print("Downloaded " + destination)
        elif response.status_code == 429:
            # Extract the Retry-After header value
            retry_after = response.headers.get("Retry-After")
            if retry_after:
                # Convert the Retry-After value to seconds
                retry_after_seconds = int(retry_after)
                print("Rate limit exceeded. Waiting for " + str(retry_after_seconds) + " seconds.")
                time.sleep(retry_after_seconds)
                # Retry the request after waiting
                download(url, destination)
            else:
                print("Rate limit exceeded. Retry-After header not found.")
        else:
            print("Website returned " + str(response.status_code))
    except urllib.error.HTTPError:
        print("Failed to download " + url)
    except Exception:
        print("Error writing " + destination)
    return

def downloadFile(url, filename):
    if not exists(filename):
        local, _ = urlretrieve(url, filename)
        print("Downloaded " + local + "\n")
        return local, _

def downloadRawFile(url, filename):
    if not os.path.exists(filename):
        # Modify the URL to the raw content URL (replace "github.com" with "raw.githubusercontent.com")
        raw_url = url + "?raw=true"
        # Download the raw content
        local, _ = downloadFile(raw_url, filename)

# %% [markdown]
# ### Useful functions.

# %%
def pretty_print_df(df, rows=None):
    if rows is not None:
        df = df.head(rows)  # Use head() to limit the DataFrame to the specified number of rows
    # Use Tabulate to show the data.
    print(tabulate(df, headers='keys', tablefmt='pretty', showindex=False))
    print("\n" + "="*40 + "\n")  # Separation between DataFrames

def find_table_by_class(soup, className):
    table = soup.find('table', class_=className)

# Prints a title decorated by stars.
def formatFancyTitle(title):
    # Calculate the length of the title
    title_length = len(title)
    # format title with decoration
    title = "*" * (title_length + 4) + "\n" + f"* {title} *" + "\n" + "*" * (title_length + 4) + "\n"
    return title

def formatTestStat(value, dec=6):
    format_string = "{:."+str(dec)+"f}"
    return format_string.format(value)

# white
TABLE_BACKGROUND_COLOR = (255, 255, 255)
# black
TABLE_FONT_COLOR = (0, 0, 0)
TABLE_FONT_SIZE = 12
TABLE_WIDTH = 600
TABLE_HEIGHT = 800
TYPEFACE_FILE = "/Library/Fonts/Menlo.ttc"

def drawText(image_filename, text, title = "", width=TABLE_WIDTH, height=TABLE_HEIGHT, background_color=TABLE_BACKGROUND_COLOR, font_name=TYPEFACE_FILE, font_color=TABLE_FONT_COLOR, font_size=TABLE_FONT_SIZE):
    # Create an image with white background
    image = Image.new('RGB', (width, height), background_color)
    # Set the font style and size
    font = ImageFont.truetype(font_name, font_size)
    # Create a drawing context
    draw = ImageDraw.Draw(image)
    # Calculate the position to start drawing the table
    x, y = 10, 10
    # Add an optional title.
    if len(title) > 0:
        text = formatFancyTitle(title) + "\n" + text
    # Draw the table onto the image
    draw.text((x, y), text, font=font, fill=font_color)
    # Save the image
    image.save(image_filename)
    return text
    
def drawTable(image_filename, table, title="", width=TABLE_WIDTH, height=TABLE_HEIGHT, background_color=TABLE_BACKGROUND_COLOR, font_name=TYPEFACE_FILE, font_color=TABLE_FONT_COLOR, font_size=TABLE_FONT_SIZE):
    text = drawText(image_filename, table, title, width, height, background_color, font_name, font_color, font_size)
    print(text)
    return text
    
def drawReport(image_filename, text, title="", width=TABLE_WIDTH, height=TABLE_HEIGHT, background_color=TABLE_BACKGROUND_COLOR, font_name=TYPEFACE_FILE, font_color=TABLE_FONT_COLOR, font_size=TABLE_FONT_SIZE):
    if len(title) > 0:
        drawText(image_filename, text, title, width, height, background_color, font_name, font_color, font_size)
        print(formatFancyTitle(title))
    else:
        drawText(image_filename, text)
    print(text)
    return text
    
# formats long tables side by side.    
def combineTables(table1, table2, table3):
    # Split the input strings into rows
    table1_rows = table1.strip().split("\n")
    table2_rows = table2.strip().split("\n")
    table3_rows = table3.strip().split("\n")
    
    max_row_count = max(len(table1_rows), len(table2_rows), len(table3_rows))
    combined_table = ""
    
    for row_idx in range(max_row_count):
        # Get the corresponding rows from each table
        table1_row = table1_rows[row_idx] if row_idx < len(table1_rows) else ""
        table2_row = table2_rows[row_idx] if row_idx < len(table2_rows) else ""
        table3_row = table3_rows[row_idx] if row_idx < len(table3_rows) else ""

        # Combine the rows into a single row
        combined_row = f"{table1_row} {table2_row} {table3_row}".strip()

        # Add the combined row to the overall table
        combined_table += combined_row + "\n"

    return combined_table

# %%
# Download the file locally. (might not have Internet this weekend)
downloadRawFile(WIKIPEDIA_PARK_RANKINGS, WIKIPEDIA_PARK_RANKINGS_FILE)

# Workaround weird character conversion issue.
encoding = "utf-8"
# Read the HTML from the URL. Force "utf-8" encoding to workaround issue.
with open(WIKIPEDIA_PARK_RANKINGS_FILE, 'r', encoding = encoding) as rankings_file:
    # Read the contents of the file into a buffer
    rankings_html = rankings_file.read()
# Out:
# Downloaded data/final/amusement_park_rankings.html

# %% [markdown]
# #### Utility functions for pretty print of data frames (later) and extracting a particular table from soup.

# %% [markdown]
# ### 2. Read the page using bs4. (Reading from a downloaded file, see note above)

# %%
# Parse the HTML using Beautiful Soup with the lxml parser
soup = BeautifulSoup(rankings_html, 'lxml')

# Find the tables
tables = soup.find_all('table')

# Initialize an empty list to store DataFrames for each table
dataframes = []

# Iterate through the first five tables (excluding the first table)
for table in tables[2:5]:
    # Convert the table to a DataFrame
    df = pd.read_html(str(table))[0]  # Assuming the first table is the one you want
    if 'Amusement Park' in df.columns:
        df['Amusement Park'] = df['Amusement Park'].apply(lambda x: x['title'] if isinstance(x, dict) and 'title' in x else x)
    dataframes.append(df)
    
    # Concatenate the DataFrames into one
all_wiki_amusement_parks_df = pd.concat(dataframes, ignore_index=True)

# Drop the 'Rank' column. Do this before finding duplicates.
all_wiki_amusement_parks_df.drop(columns=['Rank'], inplace=True)

# Remove duplicate rows based on all columns
all_wiki_amusement_parks_df.drop_duplicates(inplace=True)

# Replace NaN values with 0 in the combined DataFrame
all_wiki_amusement_parks_df.fillna(0, inplace=True)

# Convert all columns except 'Amusement Park' and 'Location' to numeric
columns_to_convert = all_wiki_amusement_parks_df.columns.difference(['Amusement park', 'Location'])
all_wiki_amusement_parks_df[columns_to_convert] = all_wiki_amusement_parks_df[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# ### Let's see the full list of amusement parks!

# %%
all_wiki_amusement_parks_df = all_wiki_amusement_parks_df.sort_values(by='Amusement park')

all_wiki_amusement_parks_df['Park number'] = ""
all_wiki_amusement_parks_df['Best match'] = ""

# Display the combined DataFrame
print(tabulate(all_wiki_amusement_parks_df.head(10), headers='keys', tablefmt='pretty', showindex=False))
# Out:
# +--------------------------------------------------------+------------------------------------+-----------+-----------+-----------+-----------+------------+------------+------------+------------+------------+------------+----------+-----------+-----------+-----------+-----------+-------------+------------+
# |                     Amusement park                     |              Location              |  2009[1]  |  2010[3]  |  2011[3]  |  2012[4]  |  2013[5]   |  2014[6]   |  2015[7]   |  2016[8]   |  2017[9]   |  2018[10]  | 2019[11] | 2020[12]  | 2021[13]  |  2010[2]  | 2021[14]  | Park number | Best match |
# +--------------------------------------------------------+------------------------------------+-----------+-----------+-----------+-----------+------------+------------+------------+------------+------------+------------
------+-----------+-----------+-----------+-----------+------------+------------+------------+------------+------------+------------+----------+-----------+-----------+-----------+-----------+-------------+------------+

# %%
print(all_wiki_amusement_parks_df[['Amusement park', 'Park number', 'Best match']])
# Out:
#                                        Amusement park Park number Best match
# 27                Alton Towers at Alton Towers Resort
# 40                                 Beto Carrero World
# 11                            Busch Gardens Tampa Bay
# 19                                Canada's Wonderland
# 10                                        Cedar Point
# 31                    Chessington World of Adventures
# 22                                        De Efteling
# 8                    Disney California Adventure Park
# 6   Disney's Animal Kingdom at Walt Disney World R...
# 3   Disney's Hollywood Studios at Walt Disney Worl...
# 4                                     Disneyland Park
# 20                Disneyland Park at Disneyland Paris
# 5                   Epcot at Walt Disney World Resort
# 21                  Europa-Park at Europa-Park Resort
# 44                                      Fantasilandia
# 37                                        Futuroscope
# 25                      Gardaland at Gardaland Resort
# 34                                         Heide Park
# 15                                        Hersheypark
# 12                                       Kings Island
# 9                                  Knott's Berry Farm
# 48                        La Feria Chapultepec Mágico
# 39                                   Legoland Billund
# 38                               Legoland Deutschland
# 30                                   Legoland Windsor
# 32                                           Liseberg
# 0   Magic Kingdom Theme Park at Walt Disney World ...
# 46                                       Mundo Petapa
# 33                                       Parc Astérix
# 43                              Parque Mundo Aventura
# 49                                Parque Plaza Sésamo
# 35                                      Parque Warner
# 42                                      Parque Xcaret
# 47                                 Parque de la Costa
# 36                                      Phantasialand
# 24            PortAventura Park at PortAventura World
# 29                                         Puy du Fou
# 13                                   SeaWorld Orlando
# 17                                 SeaWorld San Diego
# 16                          Six Flags Great Adventure
# 18                            Six Flags Great America
# 14                           Six Flags Magic Mountain
# 41                                   Six Flags México
# 45                     Theme Parque Nacional del Café
# 28                                        Thorpe Park
# 23                                     Tivoli Gardens
# 1   Universal Islands of Adventure at Universal Or...
# 2   Universal Studios Florida at Universal Orlando...
# 7                         Universal Studios Hollywood
# 26       Walt Disney Studios Park at Disneyland Paris

# %%
# Define the URL of the HTML page
url = QUEUE_TIMES_PARK_LIST_URL

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content using Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Initialize lists to store the data
    amusement_parks = []
    park_numbers = []
    countries = []

    # Find all the <div> panels
    div_panels = soup.find_all('div', class_='panel')

    # Iterate through the panels
    for panel in div_panels:
        # Find the <h2> tag inside the panel
        country_name = panel.find('h2').text.strip()
        
        # Find all the <a> tags inside the panel
        a_tags = panel.find_all('a', class_='panel-block')
        
        # Iterate through the <a> tags
        for a_tag in a_tags:
            # Extract the amusement park name and link
            amusement_park = a_tag.text.strip()
            link = a_tag['href'] 
            amusement_park = amusement_park.split("\n")[0]
            # Append the data to the lists
            amusement_parks.append(amusement_park)
            park_numbers.append(link.split("/")[-1])
            countries.append(country_name)

    # Create a DataFrame from the collected data
    QT_park_list_df = pd.DataFrame({
        'Amusement park': amusement_parks,
        'Park number': park_numbers,
        'Country': countries
    })

    # Display the DataFrame
    print(tabulate(QT_park_list_df, headers='keys', tablefmt='pretty', showindex=False))
else:
    print("Failed to fetch the URL.")
# Out:
# +-------------------------------------------+-------------+---------------------+
# |              Amusement park               | Park number |       Country       |
# +-------------------------------------------+-------------+---------------------+
# |                Familypark                 |     322     |       Austria       |
# |                Bellewaerde                |     276     |       Belgium       |
# |               Bobbejaanland               |     311     |       Belgium       |
# |            Plopsaland De Panne            |     54      |       Belgium       |
# |              Walibi Belgium               |     14      |       Belgium       |
# |            Beto Carrero World             |     319     |       Brazil        |
# |            Canada's Wonderland            |     58      |       Canada        |
# |            La Ronde, Montreal             |     48      |       Canada        |
# |          Shanghai Disney Resort           |     30      |        China        |
# |             Djurs Sommerland              |     290     |       Denmark       |
# |             Fårup Sommerland              |     18      |       Denmark       |
# |             Legoland Billund              |     52      |       Denmark       |
# |               Alton Towers                |      1      |   United Kingdom    |
# |         Blackpool Pleasure Beach          |     273     |   United Kingdom    |
# |      Chessington World of Adventures      |      3      |   United Kingdom    |
# |             Legoland Windsor              |     27      |   United Kingdom    |
# |               Paultons Park               |     49      |   United Kingdom    |
# |                Thorpe Park                |      2      |   United Kingdom    |
# |           Disneyland Park Paris           |      4      |       France        |
# |                Futuroscope                |     291     |       France        |
# |                  Le Pal                   |     303     |       France        |
# |               PanoraMagique               |     320     |       France        |
# |               Parc Astérix                |      9      |       France        |
# |                 Vulcania                  |     304     |       France        |
# |            Walibi Rhône-Alpes             |     301     |       France        |
# |         Walt Disney Studios Paris         |     28      |       France        |
# |                Europa Park                |     51      |       Germany       |
# |                Heide Park                 |     25      |       Germany       |
# |               Holiday Park                |     302     |       Germany       |
# |           Legoland Deutschland            |     278     |       Germany       |
# |            Movie Park Germany             |     310     |       Germany       |
# |               Phantasialand               |     56      |       Germany       |
# |                 Rulantica                 |     309     |       Germany       |
# |           Disneyland Hong Kong            |     31      | Hong Kong SAR China |
# |              Cinecittà World              |     318     |        Italy        |
# |                 Gardaland                 |     12      |        Italy        |
# |              Legoland Japan               |     285     |        Japan        |
# |             Tokyo Disneyland              |     274     |        Japan        |
# |              Tokyo DisneySea              |     275     |        Japan        |
# |          Universal Studios Japan          |     284     |        Japan        |
# |             Six Flags Mexico              |     47      |       Mexico        |
# |         Avonturenpark Hellendoorn         |     323     |     Netherlands     |
# |                 Efteling                  |     160     |     Netherlands     |
# |                 Toverland                 |     305     |     Netherlands     |
# |              Walibi Holland               |     53      |     Netherlands     |
# |               Energylandia                |     317     |       Poland        |
# |              Legoland Korea               |     315     |     South Korea     |
# |               Ferrari Land                |     277     |        Spain        |
# |       Parque de Atracciones Madrid        |     321     |        Spain        |
# |           Parque Warner Madrid            |     298     |        Spain        |
# |             PortAventura Park             |     19      |        Spain        |
# |                Grona Lund                 |     166     |       Sweden        |
# |                 Liseberg                  |     11      |       Sweden        |
# |             Adventure Island              |     97      |    United States    |
# |           Adventureland Resort            |     324     |    United States    |
# |              Animal Kingdom               |      8      |    United States    |
# |             Aquatica Orlando              |     94      |    United States    |
# |           Aquatica San Antonio            |     306     |    United States    |
# |            Aquatica San Diego             |     307     |    United States    |
# |            Busch Gardens Tampa            |     24      |    United States    |
# |        Busch Gardens Williamsburg         |     23      |    United States    |
# ### Fuzzy matching to move Park Number field from QT_park_list_df into all_wiki_amusement_parks_df.

# %% [markdown]
# We are trying to add a Park number column to all_wiki_amusement_parks_df['Amusement park']
# all_wiki_amusement_parks_df and QT_park_list_df both have a field called 'Amusement park', but they may not match.
# So here is the idea.
#
# # First, we find all_wiki_amusement_parks_df['Amusement park'] in QT_park_list_df['Amusement park']. If there is a match put the Park number in all_wiki_amusement_parks_df
# # Second, if no match, then find QT_park_list_df['Amusement park'] in all_wiki_amusement_parks_df['Amusement park']. If there is a match put the Park number in all_wiki_amusement_parks_df
# # Third, generate a fuzzy string comparison using distance function of Levenshtein for every unmatched entry in all_wiki_amusement_parks_df to find the entry in QT_park_list_df with the smallest return value of distance. Add the park number and
# put the result of distance in a new column called 'Distance'. The 'Distance' field will only have values if there were no matches before.
#
# # Note: Park number is a field in QT_park_list_df.
# # The goal is to create a matching Park number foor every entry in all_wiki_amusement_parks_df and add it to the dataframe.

# %%
for w, row_wiki in all_wiki_amusement_parks_df.iterrows():
    amusement_park_w = row_wiki['Amusement park']
    
    # Initialize variables to store the best match and its index
    best_match_index = None
    best_match_score = -1
    
    # Iterate through each row in QT_park_list_df
    for q, row_QT in QT_park_list_df.iterrows():
        amusement_park_Q = row_QT['Amusement park']
        
        # exact match first
        if row_wiki['Park number'] == "" and amusement_park_w == amusement_park_Q:
            print(f"Exact match for {amusement_park_w} and {amusement_park_Q}")
            all_wiki_amusement_parks_df.at[w, 'Park number'] = row_QT['Park number']
            break
            
        # if queue time string is in wiki string
        elif row_wiki['Park number'] == "" and amusement_park_w.find(amusement_park_Q) != -1:
            print(f"Near match (wiki contains QT) for {amusement_park_w} and {amusement_park_Q}")
            all_wiki_amusement_parks_df.at[w, 'Park number'] = row_QT['Park number']
            break
            
        # if wiki string is in queue time string
        elif row_wiki['Park number'] == "" and amusement_park_Q.find(amusement_park_w) != -1:
            print(f"Near match (QT contains wiki) for {amusement_park_w} and {amusement_park_Q}")
            all_wiki_amusement_parks_df.at[w, 'Park number'] = row_QT['Park number']
            break
            
        # fuzzy match
        elif row_wiki['Park number'] == "":
            fuzz_score = fuzz.ratio(amusement_park_w, amusement_park_Q)
            print(f"Fuzzy match for {amusement_park_w} and {amusement_park_Q}: {fuzz_score}")
            
            if fuzz_score > best_match_score:
                best_match_score = fuzz_score
                best_match_index = q
                
    if all_wiki_amusement_parks_df.at[w, 'Park number'] == "" and best_match_index is not None:
        all_wiki_amusement_parks_df.at[w, 'Park number'] = QT_park_list_df.at[best_match_index, 'Park number']
# Out:
# Fuzzy match for Alton Towers at Alton Towers Resort and Familypark: 9
# Fuzzy match for Alton Towers at Alton Towers Resort and Bellewaerde: 22
# Fuzzy match for Alton Towers at Alton Towers Resort and Bobbejaanland: 8
# Fuzzy match for Alton Towers at Alton Towers Resort and Plopsaland De Panne: 33
# Fuzzy match for Alton Towers at Alton Towers Resort and Walibi Belgium: 16
# Fuzzy match for Alton Towers at Alton Towers Resort and Beto Carrero World: 30
# Fuzzy match for Alton Towers at Alton Towers Resort and Canada's Wonderland: 22
# Fuzzy match for Alton Towers at Alton Towers Resort and La Ronde, Montreal: 23
# Fuzzy match for Alton Towers at Alton Towers Resort and Shanghai Disney Resort: 35
# Fuzzy match for Alton Towers at Alton Towers Resort and Djurs Sommerland: 24
# Fuzzy match for Alton Towers at Alton Towers Resort and Fårup Sommerland: 20
# Fuzzy match for Alton Towers at Alton Towers Resort and Legoland Billund: 20
# Near match (wiki contains QT) for Alton Towers at Alton Towers Resort and Alton Towers
# Fuzzy match for Beto Carrero World and Familypark: 14
# Fuzzy match for Beto Carrero World and Bellewaerde: 41
# Fuzzy match for Beto Carrero World and Bobbejaanland: 32
# Fuzzy match for Beto Carrero World and Plopsaland De Panne: 22
# Fuzzy match for Beto Carrero World and Walibi Belgium: 19
# Exact match for Beto Carrero World and Beto Carrero World
# Fuzzy match for Busch Gardens Tampa Bay and Familypark: 12
# Fuzzy match for Busch Gardens Tampa Bay and Bellewaerde: 29
# Fuzzy match for Busch Gardens Tampa Bay and Bobbejaanland: 17
# Fuzzy match for Busch Gardens Tampa Bay and Plopsaland De Panne: 19
# Fuzzy match for Busch Gardens Tampa Bay and Walibi Belgium: 16
# Fuzzy match for Busch Gardens Tampa Bay and Beto Carrero World: 24
# Fuzzy match for Busch Gardens Tampa Bay and Canada's Wonderland: 24
# Fuzzy match for Busch Gardens Tampa Bay and La Ronde, Montreal: 24
# Fuzzy match for Busch Gardens Tampa Bay and Shanghai Disney Resort: 13
# Fuzzy match for Busch Gardens Tampa Bay and Djurs Sommerland: 26
# Fuzzy match for Busch Gardens Tampa Bay and Fårup Sommerland: 21
# Fuzzy match for Busch Gardens Tampa Bay and Legoland Billund: 21
# Fuzzy match for Busch Gardens Tampa Bay and Alton Towers: 17
# Fuzzy match for Busch Gardens Tampa Bay and Blackpool Pleasure Beach: 17
# Fuzzy match for Busch Gardens Tampa Bay and Chessington World of Adventures: 26
# Fuzzy match for Busch Gardens Tampa Bay and Legoland Windsor: 10
# Fuzzy match for Busch Gardens Tampa Bay and Paultons Park: 28
# Fuzzy match for Busch Gardens Tampa Bay and Thorpe Park: 24
# Fuzzy match for Busch Gardens Tampa Bay and Disneyland Park Paris: 23
# Fuzzy match for Busch Gardens Tampa Bay and Futuroscope: 24
# Fuzzy match for Busch Gardens Tampa Bay and Le Pal: 14
# Fuzzy match for Busch Gardens Tampa Bay and PanoraMagique: 11
# Fuzzy match for Busch Gardens Tampa Bay and Parc Astérix: 17
# Fuzzy match for Busch Gardens Tampa Bay and Vulcania: 32
# Fuzzy match for Busch Gardens Tampa Bay and Walibi Rhône-Alpes: 5
# Fuzzy match for Busch Gardens Tampa Bay and Walt Disney Studios Paris: 25
# Fuzzy match for Busch Gardens Tampa Bay and Europa Park: 35
# Fuzzy match for Busch Gardens Tampa Bay and Heide Park: 18
# Fuzzy match for Busch Gardens Tampa Bay and Holiday Park: 17
# Fuzzy match for Busch Gardens Tampa Bay and Legoland Deutschland: 28
# Fuzzy match for Busch Gardens Tampa Bay and Movie Park Germany: 24
# Fuzzy match for Busch Gardens Tampa Bay and Phantasialand: 17
# Fuzzy match for Busch Gardens Tampa Bay and Rulantica: 19
# Fuzzy match for Busch Gardens Tampa Bay and Disneyland Hong Kong: 19
# Fuzzy match for Busch Gardens Tampa Bay and Cinecittà World: 21
# Fuzzy match for Busch Gardens Tampa Bay and Gardaland: 31
# Fuzzy match for Busch Gardens Tampa Bay and Legoland Japan: 22
# Fuzzy match for Busch Gardens Tampa Bay and Tokyo Disneyland: 15
# Fuzzy match for Busch Gardens Tampa Bay and Tokyo DisneySea: 11
# Fuzzy match for Busch Gardens Tampa Bay and Universal Studios Japan: 30
# Fuzzy match for Busch Gardens Tampa Bay and Six Flags Mexico: 21
# Fuzzy match for Busch Gardens Tampa Bay and Avonturenpark Hellendoorn: 21
# Fuzzy match for Busch Gardens Tampa Bay and Efteling: 13
# Fuzzy match for Busch Gardens Tampa Bay and Toverland: 12
# Fuzzy match for Busch Gardens Tampa Bay and Walibi Holland: 16
# Fuzzy match for Busch Gardens Tampa Bay and Energylandia: 17
# Fuzzy match for Busch Gardens Tampa Bay and Legoland Korea: 11
# Fuzzy match for Busch Gardens Tampa Bay and Ferrari Land: 17
# Fuzzy match for Busch Gardens Tampa Bay and Parque de Atracciones Madrid: 31
# Fuzzy match for Busch Gardens Tampa Bay and Parque Warner Madrid: 14
# Fuzzy match for Busch Gardens Tampa Bay and PortAventura Park: 20
# Fuzzy match for Busch Gardens Tampa Bay and Grona Lund: 30
# Fuzzy match for Busch Gardens Tampa Bay and Liseberg: 13
# Fuzzy match for Busch Gardens Tampa Bay and Adventure Island: 26
# Fuzzy match for Busch Gardens Tampa Bay and Adventureland Resort: 19
# Fuzzy match for Busch Gardens Tampa Bay and Animal Kingdom: 16
# Fuzzy match for Busch Gardens Tampa Bay and Aquatica Orlando: 26
# Fuzzy match for Busch Gardens Tampa Bay and Aquatica San Antonio: 23
# Fuzzy match for Busch Gardens Tampa Bay and Aquatica San Diego: 24
# Near match (wiki contains QT) for Busch Gardens Tampa Bay and Busch Gardens Tampa
# Fuzzy match for Canada's Wonderland and Familypark: 21
# Fuzzy match for Canada's Wonderland and Bellewaerde: 20
# Fuzzy match for Canada's Wonderland and Bobbejaanland: 38
# Fuzzy match for Canada's Wonderland and Plopsaland De Panne: 26
# Fuzzy match for Canada's Wonderland and Walibi Belgium: 24
# Fuzzy match for Canada's Wonderland and Beto Carrero World: 43
# Exact match for Canada's Wonderland and Canada's Wonderland
# Fuzzy match for Cedar Point and Familypark: 19
# Fuzzy match for Cedar Point and Bellewaerde: 18
# Fuzzy match for Cedar Point and Bobbejaanland: 17
# Fuzzy match for Cedar Point and Plopsaland De Panne: 27
# Fuzzy match for Cedar Point and Walibi Belgium: 16
# Fuzzy match for Cedar Point and Beto Carrero World: 34
# Fuzzy match for Cedar Point and Canada's Wonderland: 33
# Fuzzy match for Cedar Point and La Ronde, Montreal: 34
# Fuzzy match for Cedar Point and Shanghai Disney Resort: 18
# Fuzzy match for Cedar Point and Djurs Sommerland: 15
# Fuzzy match for Cedar Point and Fårup Sommerland: 15
# Fuzzy match for Cedar Point and Legoland Billund: 37
# Fuzzy match for Cedar Point and Alton Towers: 17
# Fuzzy match for Cedar Point and Blackpool Pleasure Beach: 17
# Fuzzy match for Cedar Point and Chessington World of Adventures: 24
# Fuzzy match for Cedar Point and Legoland Windsor: 37
# Fuzzy match for Cedar Point and Paultons Park: 17
# Fuzzy match for Cedar Point and Thorpe Park: 27
# Fuzzy match for Cedar Point and Disneyland Park Paris: 44
# Fuzzy match for Cedar Point and Futuroscope: 9
# Fuzzy match for Cedar Point and Le Pal: 35
# Fuzzy match for Cedar Point and PanoraMagique: 8
# Fuzzy match for Cedar Point and Parc Astérix: 35
# Fuzzy match for Cedar Point and Vulcania: 21
# Fuzzy match for Cedar Point and Walibi Rhône-Alpes: 7
# Fuzzy match for Cedar Point and Walt Disney Studios Paris: 28
# Fuzzy match for Cedar Point and Europa Park: 18
# Fuzzy match for Cedar Point and Heide Park: 38
# Fuzzy match for Cedar Point and Holiday Park: 35
# Fuzzy match for Cedar Point and Legoland Deutschland: 26
# Fuzzy match for Cedar Point and Movie Park Germany: 34
# Fuzzy match for Cedar Point and Phantasialand: 25
# Fuzzy match for Cedar Point and Rulantica: 30
# Fuzzy match for Cedar Point and Disneyland Hong Kong: 32
# Fuzzy match for Cedar Point and Cinecittà World: 31
# Fuzzy match for Cedar Point and Gardaland: 30
# Fuzzy match for Cedar Point and Legoland Japan: 32
# Fuzzy match for Cedar Point and Tokyo Disneyland: 15
# Fuzzy match for Cedar Point and Tokyo DisneySea: 15
# Fuzzy match for Cedar Point and Universal Studios Japan: 24
# Fuzzy match for Cedar Point and Six Flags Mexico: 15
# Fuzzy match for Cedar Point and Avonturenpark Hellendoorn: 33
# Fuzzy match for Cedar Point and Efteling: 32
# Fuzzy match for Cedar Point and Toverland: 20
# Fuzzy match for Cedar Point and Walibi Holland: 8
# Fuzzy match for Cedar Point and Energylandia: 26
# Fuzzy match for Cedar Point and Legoland Korea: 24
# Fuzzy match for Cedar Point and Ferrari Land: 43
# Fuzzy match for Cedar Point and Parque de Atracciones Madrid: 26
# Fuzzy match for Cedar Point and Parque Warner Madrid: 26
# Fuzzy match for Cedar Point and PortAventura Park: 21
# Fuzzy match for Cedar Point and Grona Lund: 10
# Fuzzy match for Cedar Point and Liseberg: 21
# Fuzzy match for Cedar Point and Adventure Island: 22
# Fuzzy match for Cedar Point and Adventureland Resort: 19
# Fuzzy match for Cedar Point and Animal Kingdom: 32
# Fuzzy match for Cedar Point and Aquatica Orlando: 15
# Fuzzy match for Cedar Point and Aquatica San Antonio: 26
# Fuzzy match for Cedar Point and Aquatica San Diego: 14
# Fuzzy match for Cedar Point and Busch Gardens Tampa: 20
# Fuzzy match for Cedar Point and Busch Gardens Williamsburg: 22
# Fuzzy match for Cedar Point and California's Great America: 27
# Fuzzy match for Cedar Point and Carowinds: 60
# Exact match for Cedar Point and Cedar Point
# Fuzzy match for Chessington World of Adventures and Familypark: 10
# Fuzzy match for Chessington World of Adventures and Bellewaerde: 19
# Fuzzy match for Chessington World of Adventures and Bobbejaanland: 18
# Fuzzy match for Chessington World of Adventures and Plopsaland De Panne: 24
# Fuzzy match for Chessington World of Adventures and Walibi Belgium: 13
# Fuzzy match for Chessington World of Adventures and Beto Carrero World: 37
# Fuzzy match for Chessington World of Adventures and Canada's Wonderland: 32
# Fuzzy match for Chessington World of Adventures and La Ronde, Montreal: 33
# Fuzzy match for Chessington World of Adventures and Shanghai Disney Resort: 23
# Fuzzy match for Chessington World of Adventures and Djurs Sommerland: 17
# Fuzzy match for Chessington World of Adventures and Fårup Sommerland: 17
# Fuzzy match for Chessington World of Adventures and Legoland Billund: 21
# Fuzzy match for Chessington World of Adventures and Alton Towers: 33
# Fuzzy match for Chessington World of Adventures and Blackpool Pleasure Beach: 18
# Exact match for Chessington World of Adventures and Chessington World of Adventures
# Fuzzy match for De Efteling and Familypark: 10
# Fuzzy match for De Efteling and Bellewaerde: 18
# Fuzzy match for De Efteling and Bobbejaanland: 25
# Fuzzy match for De Efteling and Plopsaland De Panne: 27
# Fuzzy match for De Efteling and Walibi Belgium: 32
# Fuzzy match for De Efteling and Beto Carrero World: 28
# Fuzzy match for De Efteling and Canada's Wonderland: 20
# Fuzzy match for De Efteling and La Ronde, Montreal: 34
# Fuzzy match for De Efteling and Shanghai Disney Resort: 12
# Fuzzy match for De Efteling and Djurs Sommerland: 30
# Fuzzy match for De Efteling and Fårup Sommerland: 22
# Fuzzy match for De Efteling and Legoland Billund: 30
# Fuzzy match for De Efteling and Alton Towers: 9
# Fuzzy match for De Efteling and Blackpool Pleasure Beach: 17
# Fuzzy match for De Efteling and Chessington World of Adventures: 19
# Fuzzy match for De Efteling and Legoland Windsor: 30
# Fuzzy match for De Efteling and Paultons Park: 8
# Fuzzy match for De Efteling and Thorpe Park: 18
# Fuzzy match for De Efteling and Disneyland Park Paris: 25
# Fuzzy match for De Efteling and Futuroscope: 9
# Fuzzy match for De Efteling and Le Pal: 35
# Fuzzy match for De Efteling and PanoraMagique: 8
# Fuzzy match for De Efteling and Parc Astérix: 26
# Fuzzy match for De Efteling and Vulcania: 21
# Fuzzy match for De Efteling and Walibi Rhône-Alpes: 21
# Fuzzy match for De Efteling and Walt Disney Studios Paris: 28
# Fuzzy match for De Efteling and Europa Park: 9
# Fuzzy match for De Efteling and Heide Park: 19
# Fuzzy match for De Efteling and Holiday Park: 17
# Fuzzy match for De Efteling and Legoland Deutschland: 32
# Fuzzy match for De Efteling and Movie Park Germany: 28
# Fuzzy match for De Efteling and Phantasialand: 25
# Fuzzy match for De Efteling and Rulantica: 20
# Fuzzy match for De Efteling and Disneyland Hong Kong: 32
# Fuzzy match for De Efteling and Cinecittà World: 15
# Fuzzy match for De Efteling and Gardaland: 20
# Fuzzy match for De Efteling and Legoland Japan: 24
# Fuzzy match for De Efteling and Tokyo Disneyland: 30
# Fuzzy match for De Efteling and Tokyo DisneySea: 23
 26
# Fuzzy match for Disneyland Park at Disneyland Paris and Heide Park: 31
# Fuzzy match for Disneyland Park at Disneyland Paris and Holiday Park: 30
# Fuzzy match for Disneyland Park at Disneyland Paris and Legoland Deutschland: 44
# Fuzzy match for Disneyland Park at Disneyland Paris and Movie Park Germany: 42
# Fuzzy match for Disneyland Park at Disneyland Paris and Phantasialand: 21
# Fuzzy match for Disneyland Park at Disneyland Paris and Rulantica: 18
# Fuzzy match for Disneyland Park at Disneyland Paris and Disneyland Hong Kong: 47
# Fuzzy match for Disneyland Park at Disneyland Paris and Cinecittà World: 20
# Fuzzy match for Disneyland Park at Disneyland Paris and Gardaland: 18
# Fuzzy match for Disneyland Park at Disneyland Paris and Legoland Japan: 37
# Fuzzy match for Disneyland Park at Disneyland Paris and Tokyo Disneyland: 47
# Fuzzy match for Disneyland Park at Disneyland Paris and Tokyo DisneySea: 36
# Fuzzy match for Disneyland Park at Disneyland Paris and Universal Studios Japan: 17
# Fuzzy match for Disneyland Park at Disneyland Paris and Six Flags Mexico: 20
# Fuzzy match for Disneyland Park at Disneyland Paris and Avonturenpark Hellendoorn: 40
# Fuzzy match for Disneyland Park at Disneyland Paris and Efteling: 9
# Fuzzy match for Disneyland Park at Disneyland Paris and Toverland: 23
# Fuzzy match for Disneyland Park at Disneyland Paris and Walibi Holland: 20
# Fuzzy match for Disneyland Park at Disneyland Paris and Energylandia: 34
# Fuzzy match for Disneyland Park at Disneyland Paris and Legoland Korea: 29
# Fuzzy match for Disneyland Park at Disneyland Paris and Ferrari Land: 17
# Fuzzy match for Disneyland Park at Disneyland Paris and Parque de Atracciones Madrid: 38
# Fuzzy match for Disneyland Park at Disneyland Paris and Parque Warner Madrid: 40
# Fuzzy match for Disneyland Park at Disneyland Paris and PortAventura Park: 27
# Fuzzy match for Disneyland Park at Disneyland Paris and Grona Lund: 18
# Fuzzy match for Disneyland Park at Disneyland Paris and Liseberg: 19
# Fuzzy match for Disneyland Park at Disneyland Paris and Adventure Island: 20
# Fuzzy match for Disneyland Park at Disneyland Paris and Adventureland Resort: 33
# Fuzzy match for Disneyland Park at Disneyland Paris and Animal Kingdom: 12
# Fuzzy match for Disneyland Park at Disneyland Paris and Aquatica Orlando: 20
# Fuzzy match for Disneyland Park at Disneyland Paris and Aquatica San Antonio: 22
# Fuzzy match for Disneyland Park at Disneyland Paris and Aquatica San Diego: 26
# Fuzzy match for Disneyland Park at Disneyland Paris and Busch Gardens Tampa: 26
# Fuzzy match for Disneyland Park at Disneyland Paris and Busch Gardens Williamsburg: 26
# Fuzzy match for Disneyland Park at Disneyland Paris and California's Great America: 30
# Fuzzy match for Disneyland Park at Disneyland Paris and Carowinds: 18
# Fuzzy match for Disneyland Park at Disneyland Paris and Cedar Point: 22
# Fuzzy match for Disneyland Park at Disneyland Paris and Discovery Cove Orlando: 32
# Fuzzy match for Disneyland Park at Disneyland Paris and Disney California Adventure: 35
# Fuzzy match for Disneyland Park at Disneyland Paris and Disney Hollywood Studios: 41
# Fuzzy match for Disneyland Park at Disneyland Paris and Disney Magic Kingdom: 33
# Near match (wiki contains QT) for Disneyland Park at Disneyland Paris and Disneyland
# Fuzzy match for Epcot at Walt Disney World Resort and Familypark: 14
# Fuzzy match for Epcot at Walt Disney World Resort and Bellewaerde: 23
# Fuzzy match for Epcot at Walt Disney World Resort and Bobbejaanland: 26
# Fuzzy match for Epcot at Walt Disney World Resort and Plopsaland De Panne: 27
# Fuzzy match for Epcot at Walt Disney World Resort and Walibi Belgium: 21
# Fuzzy match for Epcot at Walt Disney World Resort and Beto Carrero World: 39
# Fuzzy match for Epcot at Walt Disney World Resort and Canada's Wonderland: 35
# Fuzzy match for Epcot at Walt Disney World Resort and La Ronde, Montreal: 16
# Fuzzy match for Epcot at Walt Disney World Resort and Shanghai Disney Resort: 58
# Fuzzy match for Epcot at Walt Disney World Resort and Djurs Sommerland: 20
# Fuzzy match for Epcot at Walt Disney World Resort and Fårup Sommerland: 24
# Fuzzy match for Epcot at Walt Disney World Resort and Legoland Billund: 20
# Fuzzy match for Epcot at Walt Disney World Resort and Alton Towers: 18
# Fuzzy match for Epcot at Walt Disney World Resort and Blackpool Pleasure Beach: 7
# Fuzzy match for Epcot at Walt Disney World Resort and Chessington World of Adventures: 34
# Fuzzy match for Epcot at Walt Disney World Resort and Legoland Windsor: 41
# Fuzzy match for Epcot at Walt Disney World Resort and Paultons Park: 22
# Fuzzy match for Epcot at Walt Disney World Resort and Thorpe Park: 18
# Fuzzy match for Epcot at Walt Disney World Resort and Disneyland Park Paris: 37
# Fuzzy match for Epcot at Walt Disney World Resort and Futuroscope: 14
# Fuzzy match for Epcot at Walt Disney World Resort and Le Pal: 15
# Fuzzy match for Epcot at Walt Disney World Resort and PanoraMagique: 22
# Fuzzy match for Epcot at Walt Disney World Resort and Parc Astérix: 13
# Fuzzy match for Epcot at Walt Disney World Resort and Vulcania: 15
# Fuzzy match for Epcot at Walt Disney World Resort and Walibi Rhône-Alpes: 35
# Fuzzy match for Epcot at Walt Disney World Resort and Walt Disney Studios Paris: 52
# Fuzzy match for Epcot at Walt Disney World Resort and Europa Park: 23
# Fuzzy match for Epcot at Walt Disney World Resort and Heide Park: 14
# Fuzzy match for Epcot at Walt Disney World Resort and Holiday Park: 22
# Fuzzy match for Epcot at Walt Disney World Resort and Legoland Deutschland: 26
# Fuzzy match for Epcot at Walt Disney World Resort and Movie Park Germany: 27
# Fuzzy match for Epcot at Walt Disney World Resort and Phantasialand: 26
# Fuzzy match for Epcot at Walt Disney World Resort and Rulantica: 10
# Fuzzy match for Epcot at Walt Disney World Resort and Disneyland Hong Kong: 38
# Fuzzy match for Epcot at Walt Disney World Resort and Cinecittà World: 38
# Fuzzy match for Epcot at Walt Disney World Resort and Gardaland: 24
# Fuzzy match for Epcot at Walt Disney World Resort and Legoland Japan: 21
# Fuzzy match for Epcot at Walt Disney World Resort and Tokyo Disneyland: 41
# Fuzzy match for Epcot at Walt Disney World Resort and Tokyo DisneySea: 38
# Fuzzy match for Epcot at Walt Disney World Resort and Universal Studios Japan: 18
# Fuzzy match for Epcot at Walt Disney World Resort and Six Flags Mexico: 8
# Fuzzy match for Epcot at Walt Disney World Resort and Avonturenpark Hellendoorn: 14
# Fuzzy match for Epcot at Walt Disney World Resort and Efteling: 24
# Fuzzy match for Epcot at Walt Disney World Resort and Toverland: 24
# Fuzzy match for Epcot at Walt Disney World Resort and Walibi Holland: 26
# Fuzzy match for Epcot at Walt Disney World Resort and Energylandia: 27
# Fuzzy match for Epcot at Walt Disney World Resort and Legoland Korea: 21
# Fuzzy match for Epcot at Walt Disney World Resort and Ferrari Land: 18
# Fuzzy match for Epcot at Walt Disney World Resort and Parque de Atracciones Madrid: 23
# Fuzzy match for Epcot at Walt Disney World Resort and Parque Warner Madrid: 34
# Fuzzy match for Epcot at Walt Disney World Resort and PortAventura Park: 12
# Fuzzy match for Epcot at Walt Disney World Resort and Grona Lund: 19
# Fuzzy match for Epcot at Walt Disney World Resort and Liseberg: 20
# Fuzzy match for Epcot at Walt Disney World Resort and Adventure Island: 20
# Fuzzy match for Epcot at Walt Disney World Resort and Adventureland Resort: 42
# Fuzzy match for Epcot at Walt Disney World Resort and Animal Kingdom: 26
# Fuzzy match for Epcot at Walt Disney World Resort and Aquatica Orlando: 29
# Fuzzy match for Epcot at Walt Disney World Resort and Aquatica San Antonio: 26
# Fuzzy match for Epcot at Walt Disney World Resort and Aquatica San Diego: 35
# Fuzzy match for Epcot at Walt Disney World Resort and Busch Gardens Tampa: 8
# Fuzzy match for Epcot at Walt Disney World Resort and Busch Gardens Williamsburg: 27
# Fuzzy match for Epcot at Walt Disney World Resort and California's Great America: 20
# Fuzzy match for Epcot at Walt Disney World Resort and Carowinds: 14
# Fuzzy match for Epcot at Walt Disney World Resort and Cedar Point: 9
# Fuzzy match for Epcot at Walt Disney World Resort and Discovery Cove Orlando: 40
# Fuzzy match for Epcot at Walt Disney World Resort and Disney California Adventure: 40
# Fuzzy match for Epcot at Walt Disney World Resort and Disney Hollywood Studios: 42
# Fuzzy match for Epcot at Walt Disney World Resort and Disney Magic Kingdom: 30
# Fuzzy match for Epcot at Walt Disney World Resort and Disneyland: 37
# Fuzzy match for Epcot at Walt Disney World Resort and Dollywood: 24
# Fuzzy match for Epcot at Walt Disney World Resort and Dorney Park: 27
# Near match (wiki contains QT) for Epcot at Walt Disney World Resort and Epcot
# Fuzzy match for Europa-Park at Europa-Park Resort and Familypark: 19
# Fuzzy match for Europa-Park at Europa-Park Resort and Bellewaerde: 9
# Fuzzy match for Europa-Park at Europa-Park Resort and Bobbejaanland: 17
# Fuzzy match for Europa-Park at Europa-Park Resort and Plopsaland De Panne: 23
# Fuzzy match for Europa-Park at Europa-Park Resort and Walibi Belgium: 4
# Fuzzy match for Europa-Park at Europa-Park Resort and Beto Carrero World: 20
# Fuzzy match for Europa-Park at Europa-Park Resort and Canada's Wonderland: 8
# Fuzzy match for Europa-Park at Europa-Park Resort and La Ronde, Montreal: 24
# Fuzzy match for Europa-Park at Europa-Park Resort and Shanghai Disney Resort: 36
# Fuzzy match for Europa-Park at Europa-Park Resort and Djurs Sommerland: 16
# Fuzzy match for Europa-Park at Europa-Park Resort and Fårup Sommerland: 12
# Fuzzy match for Europa-Park at Europa-Park Resort and Legoland Billund: 4
# Fuzzy match for Europa-Park at Europa-Park Resort and Alton Towers: 9
# Fuzzy match for Europa-Park at Europa-Park Resort and Blackpool Pleasure Beach: 11
# Fuzzy match for Europa-Park at Europa-Park Resort and Chessington World of Adventures: 12
# Fuzzy match for Europa-Park at Europa-Park Resort and Legoland Windsor: 24
# Fuzzy match for Europa-Park at Europa-Park Resort and Paultons Park: 26
# Fuzzy match for Europa-Park at Europa-Park Resort and Thorpe Park: 27
# Fuzzy match for Europa-Park at Europa-Park Resort and Disneyland Park Paris: 37
# Fuzzy match for Europa-Park at Europa-Park Resort and Futuroscope: 27
# Fuzzy match for Europa-Park at Europa-Park Resort and Le Pal: 10
# Fuzzy match for Europa-Park at Europa-Park Resort and PanoraMagique: 17
# Fuzzy match for Europa-Park at Europa-Park Resort and Parc Astérix: 27
# Fuzzy match for Europa-Park at Europa-Park Resort and Vulcania: 15
# Fuzzy match for Europa-Park at Europa-Park Resort and Walibi Rhône-Alpes: 20
# Fuzzy match for Europa-Park at Europa-Park Resort and Walt Disney Studios Paris: 21
# ...
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Six Flags Hurricane Harbor, Oaxtepec: 22
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Six Flags Hurricane Harbor, Oklahoma City: 19
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Six Flags Hurricane Harbor, Phoenix: 20
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Six Flags Hurricane Harbor, Rockford: 22
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Six Flags Hurricane Harbor, SplashTown: 22
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Six Flags Magic Mountain: 18
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Six Flags New England: 32
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Six Flags Over Georgia: 24
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Six Flags Over Texas: 14
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Six Flags St. Louis: 22
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Six Flags White Water, Atlanta: 36
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Universal Studios At Universal Orlando: 81
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Universal Studios Hollywood: 52
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Universal Volcano Bay: 43
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Valleyfair: 13
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Water Country USA: 20
# Fuzzy match for Universal Studios Florida at Universal Orlando Resort and Worlds of Fun: 21
# Fuzzy match for Universal Studios Hollywood and Familypark: 16
# Fuzzy match for Universal Studios Hollywood and Bellewaerde: 16
# Fuzzy match for Universal Studios Hollywood and Bobbejaanland: 15
# Fuzzy match for Universal Studios Hollywood and Plopsaland De Panne: 22
# Fuzzy match for Universal Studios Hollywood and Walibi Belgium: 20
# Fuzzy match for Universal Studios Hollywood and Beto Carrero World: 18
# Fuzzy match for Universal Studios Hollywood and Canada's Wonderland: 22
# Fuzzy match for Universal Studios Hollywood and La Ronde, Montreal: 22
# Fuzzy match for Universal Studios Hollywood and Shanghai Disney Resort: 20
# Fuzzy match for Universal Studios Hollywood and Djurs Sommerland: 19
# Fuzzy match for Universal Studios Hollywood and Fårup Sommerland: 19
# Fuzzy match for Universal Studios Hollywood and Legoland Billund: 23
# Fuzzy match for Universal Studios Hollywood and Alton Towers: 21
# Fuzzy match for Universal Studios Hollywood and Blackpool Pleasure Beach: 20
# Fuzzy match for Universal Studios Hollywood and Chessington World of Adventures: 21
# Fuzzy match for Universal Studios Hollywood and Legoland Windsor: 19
# Fuzzy match for Universal Studios Hollywood and Paultons Park: 15
# Fuzzy match for Universal Studios Hollywood and Thorpe Park: 11
# Fuzzy match for Universal Studios Hollywood and Disneyland Park Paris: 12
# Fuzzy match for Universal Studios Hollywood and Futuroscope: 26
# Fuzzy match for Universal Studios Hollywood and Le Pal: 18
# Fuzzy match for Universal Studios Hollywood and PanoraMagique: 15
# Fuzzy match for Universal Studios Hollywood and Parc Astérix: 5
# Fuzzy match for Universal Studios Hollywood and Vulcania: 17
# Fuzzy match for Universal Studios Hollywood and Walibi Rhône-Alpes: 18
# Fuzzy match for Universal Studios Hollywood and Walt Disney Studios Paris: 42
# Fuzzy match for Universal Studios Hollywood and Europa Park: 16
# Fuzzy match for Universal Studios Hollywood and Heide Park: 16
# Fuzzy match for Universal Studios Hollywood and Holiday Park: 21
# Fuzzy match for Universal Studios Hollywood and Legoland Deutschland: 21
# Fuzzy match for Universal Studios Hollywood and Movie Park Germany: 22
# Fuzzy match for Universal Studios Hollywood and Phantasialand: 25
# Fuzzy match for Universal Studios Hollywood and Rulantica: 17
# Fuzzy match for Universal Studios Hollywood and Disneyland Hong Kong: 34
# Fuzzy match for Universal Studios Hollywood and Cinecittà World: 24
# Fuzzy match for Universal Studios Hollywood and Gardaland: 22
# Fuzzy match for Universal Studios Hollywood and Legoland Japan: 20
# Fuzzy match for Universal Studios Hollywood and Tokyo Disneyland: 19
# Fuzzy match for Universal Studios Hollywood and Tokyo DisneySea: 14
# Fuzzy match for Universal Studios Hollywood and Universal Studios Japan: 72
# Fuzzy match for Universal Studios Hollywood and Six Flags Mexico: 23
# Fuzzy match for Universal Studios Hollywood and Avonturenpark Hellendoorn: 35
# Fuzzy match for Universal Studios Hollywood and Efteling: 6
# Fuzzy match for Universal Studios Hollywood and Toverland: 28
# Fuzzy match for Universal Studios Hollywood and Walibi Holland: 44
# Fuzzy match for Universal Studios Hollywood and Energylandia: 31
# Fuzzy match for Universal Studios Hollywood and Legoland Korea: 20
# Fuzzy match for Universal Studios Hollywood and Ferrari Land: 26
# Fuzzy match for Universal Studios Hollywood and Parque de Atracciones Madrid: 29
# Fuzzy match for Universal Studios Hollywood and Parque Warner Madrid: 30
# Fuzzy match for Universal Studios Hollywood and PortAventura Park: 23
# Fuzzy match for Universal Studios Hollywood and Grona Lund: 27
# Fuzzy match for Universal Studios Hollywood and Liseberg: 17
# Fuzzy match for Universal Studios Hollywood and Adventure Island: 23
# Fuzzy match for Universal Studios Hollywood and Adventureland Resort: 26
# Fuzzy match for Universal Studios Hollywood and Animal Kingdom: 34
# Fuzzy match for Universal Studios Hollywood and Aquatica Orlando: 14
# Fuzzy match for Universal Studios Hollywood and Aquatica San Antonio: 13
# Fuzzy match for Universal Studios Hollywood and Aquatica San Diego: 27
# Fuzzy match for Universal Studios Hollywood and Busch Gardens Tampa: 13
# Fuzzy match for Universal Studios Hollywood and Busch Gardens Williamsburg: 19
# Fuzzy match for Universal Studios Hollywood and California's Great America: 19
# Fuzzy match for Universal Studios Hollywood and Carowinds: 11
# Fuzzy match for Universal Studios Hollywood and Cedar Point: 11
# Fuzzy match for Universal Studios Hollywood and Discovery Cove Orlando: 29
# Fuzzy match for Universal Studios Hollywood and Disney California Adventure: 22
# Fuzzy match for Universal Studios Hollywood and Disney Hollywood Studios: 47
# Fuzzy match for Universal Studios Hollywood and Disney Magic Kingdom: 21
# Fuzzy match for Universal Studios Hollywood and Disneyland: 22
# Fuzzy match for Universal Studios Hollywood and Dollywood: 44
# |                    Legoland Deutschland                    |     278     |            |
# |                      Legoland Windsor                      |     27      |            |
# |                          Liseberg                          |     11      |            |
# |    Magic Kingdom Theme Park at Walt Disney World Resort    |     30      |            |
# |                        Mundo Petapa                        |     285     |            |
# |                        Parc Astérix                        |      9      |            |
# |                   Parque Mundo Aventura                    |     321     |            |
# |                    Parque Plaza Sésamo                     |     298     |            |
# |                       Parque Warner                        |     298     |            |
# |                       Parque Xcaret                        |     298     |            |
# |                     Parque de la Costa                     |     321     |            |
# |                       Phantasialand                        |     56      |            |
# |          PortAventura Park at PortAventura World           |     19      |            |
# |                         Puy du Fou                         |     63      |            |
# |                      SeaWorld Orlando                      |     21      |            |
# |                     SeaWorld San Diego                     |     20      |            |
# |                 Six Flags Great Adventure                  |     37      |            |
# |                  Six Flags Great America                   |     38      |            |
# |                  Six Flags Magic Mountain                  |     32      |            |
# |                      Six Flags México                      |     47      |            |
# |               Theme Parque Nacional del Café               |     321     |            |
# |                        Thorpe Park                         |      2      |            |
# |                       Tivoli Gardens                       |     24      |            |
# | Universal Islands of Adventure at Universal Orlando Resort |     64      |            |
# |   Universal Studios Florida at Universal Orlando Resort    |     65      |            |
# |                Universal Studios Hollywood                 |     66      |            |
# |        Walt Disney Studios Park at Disneyland Paris        |     16      |            |
# +------------------------------------------------------------+-------------+------------+
# +-------------------------------------------+-------------+
# |              Amusement park               | Park number |
# +-------------------------------------------+-------------+
# |             Adventure Island              |     97      |
# |           Adventureland Resort            |     324     |
# |               Alton Towers                |      1      |
# |              Animal Kingdom               |      8      |
# |             Aquatica Orlando              |     94      |
# |           Aquatica San Antonio            |     306     |
# |            Aquatica San Diego             |     307     |
# |         Avonturenpark Hellendoorn         |     323     |
# |                Bellewaerde                |     276     |
# |            Beto Carrero World             |     319     |
# |         Blackpool Pleasure Beach          |     273     |
# |               Bobbejaanland               |     311     |
# |            Busch Gardens Tampa            |     24      |
# |        Busch Gardens Williamsburg         |     23      |
# |        California's Great America         |     57      |
# |            Canada's Wonderland            |     58      |
# |                 Carowinds                 |     59      |
# |                Cedar Point                |     50      |
# |      Chessington World of Adventures      |      3      |
# |              Cinecittà World              |     318     |
# |          Discovery Cove Orlando           |     308     |
# |        Disney California Adventure        |     17      |
# |         Disney Hollywood Studios          |      7      |
# |           Disney Magic Kingdom            |      6      |
# |                Disneyland                 |     16      |
# |           Disneyland Hong Kong            |     31      |
# |           Disneyland Park Paris           |      4      |
# |             Djurs Sommerland              |     290     |
# |                 Dollywood                 |     55      |
# |                Dorney Park                |     69      |
# |                 Efteling                  |     160     |
# |               Energylandia                |     317     |
# |                   Epcot                   |      5      |
# |                Europa Park                |     51      |
# |                Familypark                 |     322     |
# |               Ferrari Land                |     277     |
# |               Frontier City               |     282     |
# |                Futuroscope                |     291     |
# |             Fårup Sommerland              |     18      |
# |                 Gardaland                 |     12      |
# |                Grona Lund                 |     166     |
# |                Heide Park                 |     25      |
# |                Hersheypark                |     15      |
# |               Holiday Park                |     302     |
# | Islands Of Adventure At Universal Orlando |     64      |
# |                 Kennywood                 |     312     |
# |              Kings Dominion               |     62      |
# |               Kings Island                |     60      |
# |                 Knoebels                  |     314     |
# |            Knott's Berry Farm             |     61      |
# |            La Ronde, Montreal             |     48      |
# |              Lake Compounce               |     313     |
# |                  Le Pal                   |     303     |
# |             Legoland Billund              |     52      |
# |            Legoland California            |     279     |
# |           Legoland Deutschland            |     278     |
# |             Legoland Florida              |     280     |
# |              Legoland Japan               |     285     |
# |              Legoland Korea               |     315     |
# |             Legoland New York             |     299     |
# |             Legoland Windsor              |     27      |
# |                 Liseberg                  |     11      |
# |           Michigan's Adventure            |     70      |
# |            Movie Park Germany             |     310     |
# |               PanoraMagique               |     320     |
# |               Parc Astérix                |      9      |
# |           Parque Warner Madrid            |     298     |
# |       Parque de Atracciones Madrid        |     321     |
# |               Paultons Park               |     49      |
# |       Peppa Pig Theme Park Florida        |     316     |
# |               Phantasialand               |     56      |
# |            Plopsaland De Panne            |     54      |
# |             PortAventura Park             |     19      |
# |                 Rulantica                 |     309     |
# |             Seaworld Orlando              |     21      |
# |           Seaworld San Antonio            |     22      |
# |            Seaworld San Diego             |     20      |
# |               Sesame Place                |     29      |
# |          Shanghai Disney Resort           |     30      |
# |            Silver Dollar City             |     10      |
# |             Six Flags America             |     42      |
# |           Six Flags Darien Lake           |     281     |
# |        Six Flags Discovery Kingdom        |     33      |
# |          Six Flags Fiesta Texas           |     39      |
# |         Six Flags Great Adventure         |     37      |
# |          Six Flags Great America          |     38      |
# |          Six Flags Great Escape           |     45      |
# |   Six Flags Hurricane Harbor New Jersey   |     44      |
# |   Six Flags Hurricane Harbor, Arlington   |     40      |
# |    Six Flags Hurricane Harbor, Concord    |     293     |
# |  Six Flags Hurricane Harbor, Los Angeles  |     41      |
# |   Six Flags Hurricane Harbor, Oaxtepec    |     292     |
# | Six Flags Hurricane Harbor, Oklahoma City |     294     |
# |    Six Flags Hurricane Harbor, Phoenix    |     295     |
# |   Six Flags Hurricane Harbor, Rockford    |     297     |
# |  Six Flags Hurricane Harbor, SplashTown   |     296     |
# |         Six Flags Magic Mountain          |     32      |
# |             Six Flags Mexico              |     47      |
# |           Six Flags New England           |     43      |
# |          Six Flags Over Georgia           |     35      |
# |           Six Flags Over Texas            |     34      |
# |            Six Flags St. Louis            |     36      |
# |      Six Flags White Water, Atlanta       |     46      |
# |                Thorpe Park                |      2      |
# |              Tokyo DisneySea              |     275     |
# |             Tokyo Disneyland              |     274     |
# |                 Toverland                 |     305     |
# |  Universal Studios At Universal Orlando   |     65      |
# |        Universal Studios Hollywood        |     66      |
# |          Universal Studios Japan          |     284     |
# |           Universal Volcano Bay           |     67      |
# |                Valleyfair                 |     68      |
# |                 Vulcania                  |     304     |
# |              Walibi Belgium               |     14      |
# |              Walibi Holland               |     53      |
# |            Walibi Rhône-Alpes             |     301     |
# |         Walt Disney Studios Paris         |     28      |
# |             Water Country USA             |     96      |
# |               Worlds of Fun               |     63      |
# +-------------------------------------------+-------------+
